# %%
# !pip install opencv-python
import cv2

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ...
#   Using cached Pillow-9.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 4.1.1
#     Uninstalling Pillow-4.1.1:
#       Successfully uninstalled Pillow-4.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !pip install pytesseract

# %%
# !pip install pillow==4.1.1
# Out:
# ...
#   Using cached Pillow-4.1.1-cp37-cp37m-linux_x86_64.whl
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.1.0
#     Uninstalling Pillow-9.1.0:
#       Successfully uninstalled Pillow-9.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires pillow!=8.3.0,>=5.3.0, but you have pillow 4.1.1 which is incompatible.
# scikit-image 0.18.3 requires pillow!=7.1.0,!=7.1.1,>=4.3.0, but you have pillow 4.1.1 which is incompatible.
# pytesseract 0.3.9 requires Pillow>=8.0.0, but you have pillow 4.1.1 which is incompatible.
# bokeh 2.3.3 requires pillow>=7.1.0, but you have pillow 4.1.1 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e0e513bc-2400-44ab-8009-3efc088a0aa7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0e513bc-2400-44ab-8009-3efc088a0aa7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
import pytesseract
import numpy as np
img =cv2.imread('Adhar Card .jpg')
print(img.shape)

#img_crop=img[400:600,0:700]
img=cv2.resize(img,(400,400))
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(img.shape)
plt.imshow(img_gray)
text = pytesseract.image_to_string(img_gray)
print(text)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# (1694, 2686, 3)
# (400, 400, 3)
#
#
#
# | Baa wenad
# i NIHAR RANJAN SWAIN
#
# eg 6i6s (008: 1608/1994
# pa! Male
#
#
#
# 592777421254
# AU ae, AY ea

# %%
import numpy as np
import cv2
img =cv2.imread('Adhar Card .jpg')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Issue Date: 22/04/2013
#
# re SN
#
#
#
#
# GAIN VEE JIA
# NIHAR RANJAN SWAIN
# @G IAG / DOB: 05/03/1994
#
# Q48 / Male at
#
# 5927 7742 1254
#
# EAR AL I iD ARENA ai eta Bo
#
# ART sen, AR oe

# %%
img =cv2.imread('adhar2.jpeg')
print(img.shape)

#img_crop=img[400:600,0:700]
img=cv2.resize(img,(400,400))
#img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(img.shape)
plt.imshow(img)
text1 = pytesseract.image_to_string(img)
print(text1)
# Out:
# (632, 1029, 3)
# (400, 400, 3)
# Print Date =
#
#
#
# GRERR cee ote Bi |
# ‘ly of india’ m.
#
# ie aga crtion.gotony ZA.
#
# Goat: =e 208 004 GHA. wi
#
# ‘Address: C/O: Ananta Charan Swain,
# jin Cuttack, Ocha, 754204
#
#
#
# 5927 7742 1254
#
# Ban i gout vidal govn
# R Di] heip@uial goxin Grn

# %%
## Regular Expression TO frame them in Adhar Name,DOB,Gender,UID

# %%
import re
names= re.findall(r'[A-Z][A-Z]*',text)
print(names)
# Out:
# ['I', 'D', 'SN', 'GAIN', 'VEE', 'JIA', 'NIHAR', 'RANJAN', 'SWAIN', 'G', 'IAG', 'DOB', 'Q', 'M', 'EAR', 'AL', 'I', 'D', 'ARENA', 'B', 'ART', 'AR']

# %%
UID=re.findall("\w{4}\s\w{4}\s\w{4}",text)
print(UID)
# Out:
# ['5927 7742 1254']

# %%
Name=re.findall("\w{5}\s\w{6}\s\w{5}",text)
print(Name)
# Out:
# ['NIHAR RANJAN SWAIN']

# %%
Firstname=Name[0][0:12]
Lastname=Name[0][13:]
print(Firstname)
print(Lastname)
# Out:
# NIHAR RANJAN
# SWAIN

# %%
Gender=None
if 'Male' in text:
  Gender='Male'
else:
  Gender='Female'
print(Gender)
# Out:
# Male

# %%
Date= re.findall(r'\d{2}/\d{2}/\d{4}',text)
print(Date)
# Out:
# ['22/04/2013', '05/03/1994']

# %%
DOB=Date[1]
DOB
# Out:
# '05/03/1994'

# %%
data={'First_Name':Name[0][0:12],'Last_Name':Name[0][13:],'DOB':DOB,'Gender':Gender,'Adhar_Number':UID}

# %%
import pandas as pd
df=pd.DataFrame(data)
df
# Out:
#      First_Name Last_Name         DOB Gender    Adhar_Number
# 0  NIHAR RANJAN     SWAIN  05/03/1994   Male  5927 7742 1254

# %%
print(text1)
# Out:
# Print Date =
#
#
#
# GRERR cee ote Bi |
# ‘ly of india’ m.
#
# ie aga crtion.gotony ZA.
#
# Goat: =e 208 004 GHA. wi
#
# ‘Address: C/O: Ananta Charan Swain,
# jin Cuttack, Ocha, 754204
#
#
#
# 5927 7742 1254
#
# Ban i gout vidal govn
# R Di] heip@uial goxin Grn

# %%
pattern=re.compile(r'Address')
mat= pattern.finditer(text1)
for i in mat:
  print(i)
# Out:
# <re.Match object; span=(107, 114), match='Address'>

# %%
print(text1[116:168])
# Out:
# C/O: Ananta Charan Swain,
# jin Cuttack, Ocha, 754204

# %%
Ad=text1[116:168]
y=Ad.split(' ')
f=y[0:3]
l=y[3:8]
la=' '.join(l)
la
# Out:
# 'Swain,\njin Cuttack, Ocha, 754204\n'

# %%
pattern=r"[^a-zA-Z0-9]+"

# %%
mod_add= re.sub(pattern, ' ', la )
print(mod_add)
x=mod_add.split(' ')
x.remove('jin')
x.remove('Ocha')
add=f+x
add
# Out:
# Swain jin Cuttack Ocha 754204
# ['C/O:', 'Ananta', 'Charan', 'Swain', 'Cuttack', '754204', '']

# %%
address=' '.join(add)
address
# Out:
# 'C/O: Ananta Charan Swain Cuttack 754204 '

# %%
df['Address']=address

# %%
df
# Out:
#      First_Name Last_Name         DOB Gender    Adhar_Number  \
# 0  NIHAR RANJAN     SWAIN  05/03/1994   Male  5927 7742 1254
#
#                                     Address
# 0  C/O: Ananta Charan Swain Cuttack 754204

# %%
df=df.T
print(df)
# Out:
#                                                      0
# First_Name                                NIHAR RANJAN
# Last_Name                                        SWAIN
# DOB                                         05/03/1994
# Gender                                            Male
# Adhar_Number                            5927 7742 1254
# Address       C/O: Ananta Charan Swain Cuttack 754204
